# %%
import numpy as np
import pandas as pd

# %%
credits = pd.read_csv('../database/credits.csv')

# %%
credits
# Out:
#                                                     cast  \
# 0      [{'cast_id': 14, 'character': 'Woody (voice)',...
# 1      [{'cast_id': 1, 'character': 'Alan Parrish', '...
# 2      [{'cast_id': 2, 'character': 'Max Goldman', 'c...
# 3      [{'cast_id': 1, 'character': "Savannah 'Vannah...
# 4      [{'cast_id': 1, 'character': 'George Banks', '...
# ...                                                  ...
# 45471  [{'cast_id': 0, 'character': '', 'credit_id': ...
# 45472  [{'cast_id': 1002, 'character': 'Sister Angela...
# 45473  [{'cast_id': 6, 'character': 'Emily Shaw', 'cr...
# 45474  [{'cast_id': 2, 'character': '', 'credit_id': ...
# 45475                                                 []
#
#                                                     crew      id
# 0      [{'credit_id': '52fe4284c3a36847f8024f49', 'de...     862
# 1      [{'credit_id': '52fe44bfc3a36847f80a7cd1', 'de...    8844
# 2      [{'credit_id': '52fe466a9251416c75077a89', 'de...   15602
# ...

# %%
meta = pd.read_csv('../database/movies_metadata.csv')
# Out:
# C:\Users\Rahul\AppData\Local\Temp\ipykernel_28532\2038336406.py:1: DtypeWarning: Columns (10) have mixed types. Specify dtype option on import or set low_memory=False.
#   meta = pd.read_csv('../database/movies_metadata.csv')

# %%
meta
# Out:
#        adult                              belongs_to_collection    budget  \
# 0      False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1      False                                                NaN  65000000
# 2      False  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3      False                                                NaN  16000000
# 4      False  {'id': 96871, 'name': 'Father of the Bride Col...         0
# ...      ...                                                ...       ...
# 45460  False                                                NaN         0
# 45461  False                                                NaN         0
# 45462  False                                                NaN         0
# 45463  False                                                NaN         0
# 45464  False                                                NaN         0
#
#                                                   genres  \
# ...

# %%
ind = []
rfile = open('../database/movies_metadata.csv', 'r', encoding='utf-8')
for i, line in enumerate(rfile):
    if line[0] == ' ':
        ind.append(i)
print(ind)
rfile.close()
rfile = open('../database/movies_metadata.csv', 'r', encoding='utf-8')
wfile = open('temp.csv', 'w', encoding='utf-8')
for i, line in enumerate(rfile):
    if i+1 in ind:
        wfile.write(line.rstrip('\n'))
    else:
        wfile.write(line)
rfile.close()
wfile.close()
# Out:
# [128, 2653, 2654, 4558, 4923, 5309, 5568, 5569, 7665, 8425, 8807, 10144, 10931, 11009, 11010, 11156, 12269, 12270, 14295, 14466, 14620, 14621, 15588, 15589, 16481, 16525, 17065, 17182, 17644, 18137, 18138, 19107, 20556, 21594, 22612, 23018, 23161, 24103, 24104, 24105, 24106, 24107, 24108, 24109, 24110, 24111, 24112, 24113, 24343, 24698, 24699, 24700, 25065, 25240, 25437, 25485, 25730, 25731, 27254, 27722, 27936, 28237, 28871, 28872, 28931, 29523, 29528, 29570, 29805, 31485, 31486, 31489, 32101, 32102, 32103, 32428, 32962, 32963, 32964, 32965, 33059, 34295, 34819, 35669, 36531, 36926, 36927, 37287, 37288, 37994, 37995, 38272, 38558, 38957, 39676, 39970, 41581, 41820, 42524, 43620, 44068, 44488, 44628, 44994, 44995, 44996, 45174]

# %%
meta = pd.read_csv('temp.csv')

# %%
meta['release_date'] = pd.to_datetime(meta['release_date'], errors='coerce')

# %%
meta['year'] = meta['release_date'].dt.year

# %%
meta['year'].value_counts().sort_index()
# Out:
# 1874.0       1
# 1878.0       1
# 1883.0       1
# 1887.0       1
# 1888.0       2
#           ...
# 2015.0    1905
# 2016.0    1604
# 2017.0     532
# 2018.0       5
# 2020.0       1
# Name: year, Length: 135, dtype: int64

# %%
meta['year'].value_counts().sort_index().tail(10)
# Out:
# 2010.0    1501
# 2011.0    1667
# 2012.0    1723
# 2013.0    1889
# 2014.0    1975
# 2015.0    1905
# 2016.0    1604
# 2017.0     532
# 2018.0       5
# 2020.0       1
# Name: year, dtype: int64

# %%
new_meta = meta.loc[:,['genres','id','title','year']]

# %%
new_meta
# Out:
#                                                   genres      id  \
# 0      [{'id': 16, 'name': 'Animation'}, {'id': 35, '...     862
# 1      [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...    8844
# 2      [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...   15602
# 3      [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...   31357
# 4                         [{'id': 35, 'name': 'Comedy'}]   11862
# ...                                                  ...     ...
# 45458  [{'id': 18, 'name': 'Drama'}, {'id': 10751, 'n...  439050
# 45459                      [{'id': 18, 'name': 'Drama'}]  111109
# 45460  [{'id': 28, 'name': 'Action'}, {'id': 18, 'nam...   67758
# 45461                                                 []  227506
# 45462                                                 []  461257
#
#                              title    year
# 0                        Toy Story  1995.0
# 1                          Jumanji  1995.0
# 2                 Grumpier Old Men  1995.0
# ...

# %%
new_meta['id'] = new_meta['id'].astype(int)

# %%
data = pd.merge(new_meta, credits, on='id')

# %%
data
# Out:
#                                                   genres      id  \
# 0      [{'id': 16, 'name': 'Animation'}, {'id': 35, '...     862
# 1      [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...    8844
# 2      [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...   15602
# 3      [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...   31357
# 4                         [{'id': 35, 'name': 'Comedy'}]   11862
# ...                                                  ...     ...
# 45533  [{'id': 18, 'name': 'Drama'}, {'id': 10751, 'n...  439050
# 45534                      [{'id': 18, 'name': 'Drama'}]  111109
# 45535  [{'id': 28, 'name': 'Action'}, {'id': 18, 'nam...   67758
# 45536                                                 []  227506
# 45537                                                 []  461257
#
#                              title    year  \
# 0                        Toy Story  1995.0
# 1                          Jumanji  1995.0
# 2                 Grumpier Old Men  1995.0
# ...

# %%
# evaluates an expression node or a string containing a Python literal or container display
import ast
data['genres'] = data['genres'].map(lambda x: ast.literal_eval(x))
data['cast'] = data['cast'].map(lambda x: ast.literal_eval(x))
data['crew'] = data['crew'].map(lambda x: ast.literal_eval(x))

# %%
def make_genresList(x):
    gen = []
    st = " "
    for i in x:
        if i.get('name') == 'Science Fiction':
            scifi = 'Sci-Fi'
            gen.append(scifi)
        else:
            gen.append(i.get('name'))
    if gen == []:
        return np.NaN
    else:
        return (st.join(gen))

# %%
data['genres_list'] = data['genres'].map(lambda x: make_genresList(x))

# %%
data['genres_list']
# Out:
# 0         Animation Comedy Family
# 1        Adventure Fantasy Family
# 2                  Romance Comedy
# 3            Comedy Drama Romance
# 4                          Comedy
#                    ...
# 45533                Drama Family
# 45534                       Drama
# 45535       Action Drama Thriller
# 45536                         NaN
# 45537                         NaN
# Name: genres_list, Length: 45538, dtype: object

# %%
data
# Out:
#                                                   genres      id  \
# 0      [{'id': 16, 'name': 'Animation'}, {'id': 35, '...     862
# 1      [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...    8844
# 2      [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...   15602
# 3      [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...   31357
# 4                         [{'id': 35, 'name': 'Comedy'}]   11862
# ...                                                  ...     ...
# 45533  [{'id': 18, 'name': 'Drama'}, {'id': 10751, 'n...  439050
# 45534                      [{'id': 18, 'name': 'Drama'}]  111109
# 45535  [{'id': 28, 'name': 'Action'}, {'id': 18, 'nam...   67758
# 45536                                                 []  227506
# 45537                                                 []  461257
#
#                              title    year  \
# 0                        Toy Story  1995.0
# 1                          Jumanji  1995.0
# 2                 Grumpier Old Men  1995.0
# ...

# %%
def get_actor1(x):
    casts = []
    for i in x:
        casts.append(i.get('name'))
    if casts == []:
        return np.NaN
    else:
        return (casts[0])

# %%
data['actor_1_name'] = data['cast'].map(lambda x: get_actor1(x))

# %%
def get_actor2(x):
    casts = []
    for i in x:
        casts.append(i.get('name'))
    if casts == [] or len(casts)<=1:
        return np.NaN
    else:
        return (casts[1])

# %%
data['actor_2_name'] = data['cast'].map(lambda x: get_actor2(x))

# %%
data['actor_2_name']
# Out:
# 0                Tim Allen
# 1            Jonathan Hyde
# 2              Jack Lemmon
# 3           Angela Bassett
# 4             Diane Keaton
#                ...
# 45533       Kourosh Tahami
# 45534          Perry Dizon
# 45535         Adam Baldwin
# 45536    Nathalie Lissenko
# 45537                  NaN
# Name: actor_2_name, Length: 45538, dtype: object

# %%
def get_actor3(x):
    casts = []
    for i in x:
        casts.append(i.get('name'))
    if casts == [] or len(casts)<=2:
        return np.NaN
    else:
        return (casts[2])

# %%
data['actor_3_name'] = data['cast'].map(lambda x: get_actor3(x))

# %%
data['actor_3_name']
# Out:
# 0           Don Rickles
# 1         Kirsten Dunst
# 2           Ann-Margret
# 3        Loretta Devine
# 4          Martin Short
#               ...
# 45533       Elham Korda
# 45534     Hazel Orencio
# 45535     Julie du Page
# 45536      Pavel Pavlov
# 45537               NaN
# Name: actor_3_name, Length: 45538, dtype: object

# %%
def get_directors(x):
    dt = []
    st = " "
    for i in x:
        if i.get('job') == 'Director':
            dt.append(i.get('name'))
    if dt == []:
        return np.NaN
    else:
        return (st.join(dt))

# %%
data['director_name'] = data['crew'].map(lambda x: get_directors(x))

# %%
data['director_name']
# Out:
# 0           John Lasseter
# 1            Joe Johnston
# 2           Howard Deutch
# 3         Forest Whitaker
# 4           Charles Shyer
#                ...
# 45533    Hamid Nematollah
# 45534            Lav Diaz
# 45535      Mark L. Lester
# 45536    Yakov Protazanov
# 45537       Daisy Asquith
# Name: director_name, Length: 45538, dtype: object

# %%
movie = data.loc[:,['director_name','actor_1_name','actor_2_name','actor_3_name','genres_list','title']]

# %%
movie
# Out:
#           director_name      actor_1_name       actor_2_name    actor_3_name  \
# 0         John Lasseter         Tom Hanks          Tim Allen     Don Rickles
# 1          Joe Johnston    Robin Williams      Jonathan Hyde   Kirsten Dunst
# 2         Howard Deutch    Walter Matthau        Jack Lemmon     Ann-Margret
# 3       Forest Whitaker   Whitney Houston     Angela Bassett  Loretta Devine
# 4         Charles Shyer      Steve Martin       Diane Keaton    Martin Short
# ...                 ...               ...                ...             ...
# 45533  Hamid Nematollah      Leila Hatami     Kourosh Tahami     Elham Korda
# 45534          Lav Diaz      Angel Aquino        Perry Dizon   Hazel Orencio
# 45535    Mark L. Lester     Erika Eleniak       Adam Baldwin   Julie du Page
# 45536  Yakov Protazanov  Iwan Mosschuchin  Nathalie Lissenko    Pavel Pavlov
# 45537     Daisy Asquith               NaN                NaN             NaN
#
# ...

# %%
movie.isna().sum()
# Out:
# director_name     887
# actor_1_name     2420
# actor_2_name     3752
# actor_3_name     4664
# genres_list      2442
# title               0
# dtype: int64

# %%
movie = movie.dropna(how='any')

# %%
movie.isna().sum()
# Out:
# director_name    0
# actor_1_name     0
# actor_2_name     0
# actor_3_name     0
# genres_list      0
# title            0
# dtype: int64

# %%
movie = movie.rename(columns={'genres_list':'genres'})
movie = movie.rename(columns={'title':'movie_title'})

# %%
movie['movie_title'] = movie['movie_title'].str.lower()

# %%
movie['comb'] = movie['actor_1_name'] + ' ' + movie['actor_2_name'] + ' '+ movie['actor_3_name'] + ' '+ movie['director_name'] +' ' + movie['genres']

# %%
movie
# Out:
#           director_name     actor_1_name    actor_2_name     actor_3_name  \
# 0         John Lasseter        Tom Hanks       Tim Allen      Don Rickles
# 1          Joe Johnston   Robin Williams   Jonathan Hyde    Kirsten Dunst
# 2         Howard Deutch   Walter Matthau     Jack Lemmon      Ann-Margret
# 3       Forest Whitaker  Whitney Houston  Angela Bassett   Loretta Devine
# 4         Charles Shyer     Steve Martin    Diane Keaton     Martin Short
# ...                 ...              ...             ...              ...
# 45531     Aaron Osborne       Lisa Boyle       Kena Land    Zaneta Polard
# 45532        John Irvin   Patrick Bergin     Uma Thurman  David Morrissey
# 45533  Hamid Nematollah     Leila Hatami  Kourosh Tahami      Elham Korda
# 45534          Lav Diaz     Angel Aquino     Perry Dizon    Hazel Orencio
# 45535    Mark L. Lester    Erika Eleniak    Adam Baldwin    Julie du Page
#
#                          genres                  movie_title  \
# ...

# %%
movie.drop_duplicates(subset ="movie_title", keep = 'last', inplace = True)

# %%
movie
# Out:
#           director_name     actor_1_name    actor_2_name     actor_3_name  \
# 0         John Lasseter        Tom Hanks       Tim Allen      Don Rickles
# 1          Joe Johnston   Robin Williams   Jonathan Hyde    Kirsten Dunst
# 2         Howard Deutch   Walter Matthau     Jack Lemmon      Ann-Margret
# 3       Forest Whitaker  Whitney Houston  Angela Bassett   Loretta Devine
# 4         Charles Shyer     Steve Martin    Diane Keaton     Martin Short
# ...                 ...              ...             ...              ...
# 45531     Aaron Osborne       Lisa Boyle       Kena Land    Zaneta Polard
# 45532        John Irvin   Patrick Bergin     Uma Thurman  David Morrissey
# 45533  Hamid Nematollah     Leila Hatami  Kourosh Tahami      Elham Korda
# 45534          Lav Diaz     Angel Aquino     Perry Dizon    Hazel Orencio
# 45535    Mark L. Lester    Erika Eleniak    Adam Baldwin    Julie du Page
#
#                          genres                  movie_title  \
# ...

# %%
movie.to_csv('data2017.csv', index=False)
