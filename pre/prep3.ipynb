# %%
import pandas as pd
import numpy as np

# %%
link = "https://en.wikipedia.org/wiki/List_of_American_films_of_2020"
df1 = pd.read_html(link, header=0)[2]
df2 = pd.read_html(link, header=0)[3]
df3 = pd.read_html(link, header=0)[4]
df4 = pd.read_html(link, header=0)[5]

# %%
df = df1.append(df2.append(df3.append(df4,ignore_index=True),ignore_index=True),ignore_index=True)
# Out:
# C:\Users\Rahul\AppData\Local\Temp\ipykernel_30184\1752420719.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df1.append(df2.append(df3.append(df4,ignore_index=True),ignore_index=True),ignore_index=True)

# %%
from tmdbv3api import TMDb
import json
import requests
tmdb = TMDb()
tmdb.api_key = '88a8684a8e00e52d426f3128553555c0'

# %%
from tmdbv3api import Movie
tmdb_movie = Movie() 
def get_genre(x):
    genres = []
    result = tmdb_movie.search(x)
    if not result:
      return np.NaN
    else:
      movie_id = result[0].id
      response = requests.get('https://api.themoviedb.org/3/movie/{}?api_key={}'.format(movie_id,tmdb.api_key))
      data_json = response.json()
      if data_json['genres']:
          genre_str = " " 
          for i in range(0,len(data_json['genres'])):
              genres.append(data_json['genres'][i]['name'])
          return genre_str.join(genres)
      else:
          return np.NaN

# %%
df['genres'] = df['Title'].map(lambda x: get_genre(str(x)))

# %%
df
# Out:
#              Opening  Opening.1                  Title  \
# 0      J A N U A R Y          3             The Grudge
# 1      J A N U A R Y         10             Underwater
# 2      J A N U A R Y         10            Like a Boss
# 3      J A N U A R Y         10          Three Christs
# 4      J A N U A R Y         10      Inherit the Viper
# ..               ...        ...                    ...
# 271  D E C E M B E R         25       We Can Be Heroes
# 272  D E C E M B E R         25      News of the World
# 273  D E C E M B E R         25  One Night in Miami...
# 274  D E C E M B E R         25  Promising Young Woman
# 275  D E C E M B E R         30      Pieces of a Woman
#
#                                     Production company  \
# 0    Screen Gems / Stage 6 Films / Ghost House Pict...
# 1    20th Century Fox / TSG Entertainment / Chernin...
# 2                   Paramount Pictures / Artists First
# 3                                            IFC Films
# 4       Barry Films / Tycor International Film Company
# ..                                                 ...
# 271  Netflix / Troublemaker Studios / Double R Prod...
# 272        Universal Pictures / Perfect World Pictures
# 273                                     Amazon Studios
# 274          Focus Features / FilmNation Entertainment
# 275                             Netflix / Bron Studios
#
#                                          Cast and crew  \
# 0    Nicolas Pesce (director/screenplay); Andrea Ri...
# 1    William Eubank (director); Brian Duffield, Ada...
# 2    Miguel Arteta (director); Sam Pitman, Adam Col...
# 3    Jon Avnet (director/screenplay); Eric Nazarian...
# 4    Anthony Jerjen (director); Andrew Crabtree (sc...
# ..                                                 ...
# 271  Robert Rodriguez (director/screenplay); Priyan...
# 272  Paul Greengrass (director/screenplay); Luke Da...
# 273  Regina King (director); Kemp Powers (screenpla...
# 274  Emerald Fennell (director/screenplay); Carey M...
# 275  Kornél Mundruczó (director); Kata Wéber (scree...
#
#     .mw-parser-output .tooltip-dotted{border-bottom:1px dotted;cursor:help}Ref.  \
# 0                                                  [2]
# 1                                                  [3]
# 2                                                  [4]
# 3                                                  NaN
# 4                                                  [5]
# ..                                                 ...
# 271                                                NaN
# 272                                                NaN
# 273                                                NaN
# 274                                                NaN
# 275                                                NaN
#
#       Ref.                                   genres
# 0      NaN                           Horror Mystery
# 1      NaN  Horror Science Fiction Action Adventure
# 2      NaN                                   Comedy
# 3      NaN                                    Drama
# 4      NaN                     Crime Thriller Drama
# ..     ...                                      ...
# 271  [242]             Action Fantasy Family Comedy
# 272  [243]           Drama Western Adventure Action
# 273  [244]                                    Drama
# 274  [245]                     Thriller Crime Drama
# 275  [246]                                    Drama
#
# [276 rows x 8 columns]

# %%
df_2020 = df.loc[:, ['Title','Cast and crew','genres']]

# %%
df_2020
# Out:
#                      Title                                      Cast and crew  \
# 0               The Grudge  Nicolas Pesce (director/screenplay); Andrea Ri...
# 1               Underwater  William Eubank (director); Brian Duffield, Ada...
# 2              Like a Boss  Miguel Arteta (director); Sam Pitman, Adam Col...
# 3            Three Christs  Jon Avnet (director/screenplay); Eric Nazarian...
# 4        Inherit the Viper  Anthony Jerjen (director); Andrew Crabtree (sc...
# ..                     ...                                                ...
# 271       We Can Be Heroes  Robert Rodriguez (director/screenplay); Priyan...
# 272      News of the World  Paul Greengrass (director/screenplay); Luke Da...
# 273  One Night in Miami...  Regina King (director); Kemp Powers (screenpla...
# 274  Promising Young Woman  Emerald Fennell (director/screenplay); Carey M...
# 275      Pieces of a Woman  Kornél Mundruczó (director); Kata Wéber (scree...
#
#                                       genres
# 0                             Horror Mystery
# 1    Horror Science Fiction Action Adventure
# 2                                     Comedy
# 3                                      Drama
# 4                       Crime Thriller Drama
# ..                                       ...
# 271             Action Fantasy Family Comedy
# 272           Drama Western Adventure Action
# 273                                    Drama
# 274                     Thriller Crime Drama
# 275                                    Drama
#
# [276 rows x 3 columns]

# %%
def get_director(x):
    if " (director)" in x:
        return x.split(" (director)")[0]
    elif " (directors)" in x:
        return x.split(" (directors)")[0]
    else:
        return x.split(" (director/screenplay)")[0]

# %%
def get_actor1(x):
    return ((x.split("screenplay); ")[-1]).split(", ")[0])

# %%
def get_actor2(x):
    if len((x.split("screenplay); ")[-1]).split(", ")) < 2:
        return np.NaN
    else:
        return ((x.split("screenplay); ")[-1]).split(", ")[1])

# %%
def get_actor3(x):
    if len((x.split("screenplay); ")[-1]).split(", ")) < 3:
        return np.NaN
    else:
        return ((x.split("screenplay); ")[-1]).split(", ")[2])

# %%
df_2020['director_name'] = df_2020['Cast and crew'].map(lambda x: get_director(x))

# %%
df_2020['actor_1_name'] = df_2020['Cast and crew'].map(lambda x: get_actor1(x))

# %%
df_2020['actor_2_name'] = df_2020['Cast and crew'].map(lambda x: get_actor2(x))

# %%
df_2020['actor_3_name'] = df_2020['Cast and crew'].map(lambda x: get_actor3(x))

# %%
df_2020 = df_2020.rename(columns={'Title':'movie_title'})

# %%
new_df20 = df_2020.loc[:,['director_name','actor_1_name','actor_2_name','actor_3_name','genres','movie_title']]

# %%
new_df20['actor_2_name'] = new_df20['actor_2_name'].replace(np.nan, 'unknown')
new_df20['actor_3_name'] = new_df20['actor_3_name'].replace(np.nan, 'unknown')

# %%
new_df20['movie_title'] = new_df20['movie_title'].str.lower()

# %%
new_df20['comb'] = new_df20['actor_1_name'] + ' ' + new_df20['actor_2_name'] + ' '+ new_df20['actor_3_name'] + ' '+ new_df20['director_name'] +' ' + new_df20['genres']

# %%
new_df20
# Out:
#         director_name           actor_1_name       actor_2_name  \
# 0       Nicolas Pesce     Andrea Riseborough      Demián Bichir
# 1      William Eubank        Kristen Stewart     Vincent Cassel
# 2       Miguel Arteta        Tiffany Haddish         Rose Byrne
# 3           Jon Avnet           Richard Gere     Peter Dinklage
# 4      Anthony Jerjen          Josh Hartnett  Margarita Levieva
# ..                ...                    ...                ...
# 271  Robert Rodriguez  Priyanka Chopra Jonas       Pedro Pascal
# 272   Paul Greengrass              Tom Hanks      Helena Zengel
# 273       Regina King      Kingsley Ben-Adir          Eli Goree
# 274   Emerald Fennell         Carey Mulligan         Bo Burnham
# 275  Kornél Mundruczó          Vanessa Kirby       Shia LaBeouf
#
#         actor_3_name                                   genres  \
# 0           John Cho                           Horror Mystery
# 1    Jessica Henwick  Horror Science Fiction Action Adventure
# 2        Salma Hayek                                   Comedy
# 3     Walton Goggins                                    Drama
# 4     Chandler Riggs                     Crime Thriller Drama
# ..               ...                                      ...
# 271    YaYa Gosselin             Action Fantasy Family Comedy
# 272          unknown           Drama Western Adventure Action
# 273      Aldis Hodge                                    Drama
# 274      Alison Brie                     Thriller Crime Drama
# 275     Molly Parker                                    Drama
#
#                movie_title                                               comb
# 0               the grudge  Andrea Riseborough Demián Bichir John Cho Nico...
# 1               underwater  Kristen Stewart Vincent Cassel Jessica Henwick...
# 2              like a boss  Tiffany Haddish Rose Byrne Salma Hayek Miguel ...
# 3            three christs  Richard Gere Peter Dinklage Walton Goggins Jon...
# 4        inherit the viper  Josh Hartnett Margarita Levieva Chandler Riggs...
# ..                     ...                                                ...
# 271       we can be heroes  Priyanka Chopra Jonas Pedro Pascal YaYa Gossel...
# 272      news of the world  Tom Hanks Helena Zengel unknown Paul Greengras...
# 273  one night in miami...  Kingsley Ben-Adir Eli Goree Aldis Hodge Regina...
# 274  promising young woman  Carey Mulligan Bo Burnham Alison Brie Emerald ...
# 275      pieces of a woman  Vanessa Kirby Shia LaBeouf Molly Parker Kornél...
#
# [276 rows x 7 columns]

# %%
link = "https://en.wikipedia.org/wiki/List_of_American_films_of_2021"
df1 = pd.read_html(link, header=0)[2]
df2 = pd.read_html(link, header=0)[3]
df3 = pd.read_html(link, header=0)[4]
df4 = pd.read_html(link, header=0)[5]

# %%
df = df1.append(df2.append(df3.append(df4,ignore_index=True),ignore_index=True),ignore_index=True)
# Out:
# C:\Users\Rahul\AppData\Local\Temp\ipykernel_30184\1752420719.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df1.append(df2.append(df3.append(df4,ignore_index=True),ignore_index=True),ignore_index=True)

# %%
df
# Out:
#              Opening  Opening.1                   Title  \
# 0      J A N U A R Y        1.0     Shadow in the Cloud
# 1      J A N U A R Y       13.0         The White Tiger
# 2      J A N U A R Y       14.0             Locked Down
# 3      J A N U A R Y       15.0                 The Dig
# 4      J A N U A R Y       15.0        Outside the Wire
# ..               ...        ...                     ...
# 356  D E C E M B E R       25.0  The Tragedy of Macbeth
# 357  D E C E M B E R       25.0    A Journal for Jordan
# 358  D E C E M B E R       25.0       American Underdog
# 359  D E C E M B E R       26.0                 Memoria
# 360  D E C E M B E R        NaN                     NaN
#
#                                     Production company  \
# 0                               Vertical Entertainment
# 1                                Netflix / Noruz Films
# 2                      HBO Max / Warner Bros. Pictures
# 3                          Netflix / Clerkenwell Films
# 4                                              Netflix
# ..                                                 ...
# 356                        Apple TV+ / A24 / IAC Films
# 357  Columbia Pictures / Escape Artists / Bron Studios
# 358                                          Lionsgate
# 359                                               Neon
# 360                                                NaN
#
#                                          Cast and crew  \
# 0    Roseanne Liang (director/screenplay); Max Land...
# 1    Ramin Bahrani (director/screenplay); Adarsh Go...
# 2    Doug Liman (director); Steven Knight (screenpl...
# 3    Simon Stone (director); Moira Buffini (screenp...
# 4    Mikael Håfström (director); Rob Yescombe, Rowa...
# ..                                                 ...
# 356  Joel Coen (director/screenplay); Denzel Washin...
# 357  Denzel Washington (director); Virgil Williams ...
# 358  Erwin brothers (directors); Jon Erwin, David A...
# 359  Apichatpong Weerasethakul (director/acreenplay...
# 360                                                NaN
#
#     .mw-parser-output .tooltip-dotted{border-bottom:1px dotted;cursor:help}Ref.  \
# 0                                                  [2]
# 1                                                  NaN
# 2                                                  [3]
# 3                                                  [4]
# 4                                                  [5]
# ..                                                 ...
# 356                                                NaN
# 357                                                NaN
# 358                                                NaN
# 359                                                NaN
# 360                                                NaN
#
#       Ref.
# 0      NaN
# 1      NaN
# 2      NaN
# 3      NaN
# 4      NaN
# ..     ...
# 356  [273]
# 357  [274]
# 358  [275]
# 359  [276]
# 360    NaN
#
# [361 rows x 7 columns]

# %%
df['genres'] = df['Title'].map(lambda x: get_genre(str(x)))

# %%
df_2021 = df.loc[:, ['Title','Cast and crew','genres']]

# %%
df_2021
# Out:
#                       Title  \
# 0       Shadow in the Cloud
# 1           The White Tiger
# 2               Locked Down
# 3                   The Dig
# 4          Outside the Wire
# ..                      ...
# 356  The Tragedy of Macbeth
# 357    A Journal for Jordan
# 358       American Underdog
# 359                 Memoria
# 360                     NaN
#
#                                          Cast and crew  \
# 0    Roseanne Liang (director/screenplay); Max Land...
# 1    Ramin Bahrani (director/screenplay); Adarsh Go...
# 2    Doug Liman (director); Steven Knight (screenpl...
# 3    Simon Stone (director); Moira Buffini (screenp...
# 4    Mikael Håfström (director); Rob Yescombe, Rowa...
# ..                                                 ...
# 356  Joel Coen (director/screenplay); Denzel Washin...
# 357  Denzel Washington (director); Virgil Williams ...
# 358  Erwin brothers (directors); Jon Erwin, David A...
# 359  Apichatpong Weerasethakul (director/acreenplay...
# 360                                                NaN
#
#                               genres
# 0                  Horror Action War
# 1                              Drama
# 2                 Comedy Crime Drama
# 3                      Drama History
# 4    Thriller Action Science Fiction
# ..                               ...
# 356                        Drama War
# 357                    Drama Romance
# 358                            Drama
# 359                            Drama
# 360                            Drama
#
# [361 rows x 3 columns]

# %%
df_2021['director_name'] = df_2021['Cast and crew'].map(lambda x: get_director(str(x)))

# %%
df_2021['actor_1_name'] = df_2021['Cast and crew'].map(lambda x: get_actor1(str(x)))

# %%
df_2021['actor_2_name'] = df_2021['Cast and crew'].map(lambda x: get_actor2(str(x)))

# %%
df_2021['actor_3_name'] = df_2021['Cast and crew'].map(lambda x: get_actor3(str(x)))

# %%
df_2021 = df_2021.rename(columns={'Title':'movie_title'})

# %%
new_df21 = df_2021.loc[:,['director_name','actor_1_name','actor_2_name','actor_3_name','genres','movie_title']]

# %%
new_df21['actor_2_name'] = new_df21['actor_2_name'].replace(np.nan, 'unknown')
new_df21['actor_3_name'] = new_df21['actor_3_name'].replace(np.nan, 'unknown')

# %%
new_df21['movie_title'] = new_df21['movie_title'].str.lower()

# %%
new_df21['comb'] = new_df21['actor_1_name'] + ' ' + new_df21['actor_2_name'] + ' '+ new_df21['actor_3_name'] + ' '+ new_df21['director_name'] +' ' + new_df21['genres']

# %%
new_df21
# Out:
#                                          director_name  \
# 0                                       Roseanne Liang
# 1                                        Ramin Bahrani
# 2                                           Doug Liman
# 3                                          Simon Stone
# 4                                      Mikael Håfström
# ..                                                 ...
# 356                                          Joel Coen
# 357                                  Denzel Washington
# 358                                     Erwin brothers
# 359  Apichatpong Weerasethakul (director/acreenplay...
# 360                                                nan
#
#                                           actor_1_name       actor_2_name  \
# 0                                   Chloë Grace Moretz  Taylor John Smith
# 1                                        Adarsh Gourav      Rajkummar Rao
# 2                                        Anne Hathaway   Chiwetel Ejiofor
# 3                                       Carey Mulligan      Ralph Fiennes
# 4                                       Anthony Mackie       Damson Idris
# ..                                                 ...                ...
# 356                                  Denzel Washington  Frances McDormand
# 357                                  Michael B. Jordan       Chanté Adams
# 358                                       Zachary Levi        Anna Paquin
# 359  Apichatpong Weerasethakul (director/acreenplay...         Elkin Díaz
# 360                                                nan            unknown
#
#               actor_3_name                           genres  \
# 0             Beulah Koale                Horror Action War
# 1    Priyanka Chopra Jonas                            Drama
# 2         Stephen Merchant               Comedy Crime Drama
# 3               Lily James                    Drama History
# 4            Emily Beecham  Thriller Action Science Fiction
# ..                     ...                              ...
# 356          Bertie Carvel                        Drama War
# 357        Jalon Christian                    Drama Romance
# 358           Dennis Quaid                            Drama
# 359         Jeanne Balibar                            Drama
# 360                unknown                            Drama
#
#                 movie_title                                               comb
# 0       shadow in the cloud  Chloë Grace Moretz Taylor John Smith Beulah Ko...
# 1           the white tiger  Adarsh Gourav Rajkummar Rao Priyanka Chopra Jo...
# 2               locked down  Anne Hathaway Chiwetel Ejiofor Stephen Merchan...
# 3                   the dig  Carey Mulligan Ralph Fiennes Lily James Simon ...
# 4          outside the wire  Anthony Mackie Damson Idris Emily Beecham Mika...
# ..                      ...                                                ...
# 356  the tragedy of macbeth  Denzel Washington Frances McDormand Bertie Car...
# 357    a journal for jordan  Michael B. Jordan Chanté Adams Jalon Christian...
# 358       american underdog  Zachary Levi Anna Paquin Dennis Quaid Erwin br...
# 359                 memoria  Apichatpong Weerasethakul (director/acreenplay...
# 360                     NaN                      nan unknown unknown nan Drama
#
# [361 rows x 7 columns]

# %%
my_df = new_df20.append(new_df21,ignore_index=True)
# Out:
# C:\Users\Rahul\AppData\Local\Temp\ipykernel_30184\2792808767.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   my_df = new_df20.append(new_df21,ignore_index=True)

# %%
my_df
# Out:
#                                          director_name  \
# 0                                        Nicolas Pesce
# 1                                       William Eubank
# 2                                        Miguel Arteta
# 3                                            Jon Avnet
# 4                                       Anthony Jerjen
# ..                                                 ...
# 632                                          Joel Coen
# 633                                  Denzel Washington
# 634                                     Erwin brothers
# 635  Apichatpong Weerasethakul (director/acreenplay...
# 636                                                nan
#
#                                           actor_1_name       actor_2_name  \
# 0                                   Andrea Riseborough      Demián Bichir
# 1                                      Kristen Stewart     Vincent Cassel
# 2                                      Tiffany Haddish         Rose Byrne
# 3                                         Richard Gere     Peter Dinklage
# 4                                        Josh Hartnett  Margarita Levieva
# ..                                                 ...                ...
# 632                                  Denzel Washington  Frances McDormand
# 633                                  Michael B. Jordan       Chanté Adams
# 634                                       Zachary Levi        Anna Paquin
# 635  Apichatpong Weerasethakul (director/acreenplay...         Elkin Díaz
# 636                                                nan            unknown
#
#         actor_3_name                                   genres  \
# 0           John Cho                           Horror Mystery
# 1    Jessica Henwick  Horror Science Fiction Action Adventure
# 2        Salma Hayek                                   Comedy
# 3     Walton Goggins                                    Drama
# 4     Chandler Riggs                     Crime Thriller Drama
# ..               ...                                      ...
# 632    Bertie Carvel                                Drama War
# 633  Jalon Christian                            Drama Romance
# 634     Dennis Quaid                                    Drama
# 635   Jeanne Balibar                                    Drama
# 636          unknown                                    Drama
#
#                 movie_title                                               comb
# 0                the grudge  Andrea Riseborough Demián Bichir John Cho Nico...
# 1                underwater  Kristen Stewart Vincent Cassel Jessica Henwick...
# 2               like a boss  Tiffany Haddish Rose Byrne Salma Hayek Miguel ...
# 3             three christs  Richard Gere Peter Dinklage Walton Goggins Jon...
# 4         inherit the viper  Josh Hartnett Margarita Levieva Chandler Riggs...
# ..                      ...                                                ...
# 632  the tragedy of macbeth  Denzel Washington Frances McDormand Bertie Car...
# 633    a journal for jordan  Michael B. Jordan Chanté Adams Jalon Christian...
# 634       american underdog  Zachary Levi Anna Paquin Dennis Quaid Erwin br...
# 635                 memoria  Apichatpong Weerasethakul (director/acreenplay...
# 636                     NaN                      nan unknown unknown nan Drama
#
# [637 rows x 7 columns]

# %%
old_df = pd.read_csv('data2019.csv')

# %%
old_df
# Out:
#                 director_name       actor_1_name          actor_2_name  \
# 0               John Lasseter          Tom Hanks             Tim Allen
# 1                Joe Johnston     Robin Williams         Jonathan Hyde
# 2               Howard Deutch     Walter Matthau           Jack Lemmon
# 3             Forest Whitaker    Whitney Houston        Angela Bassett
# 4               Charles Shyer       Steve Martin          Diane Keaton
# ...                       ...                ...                   ...
# 36871  Nick Bruno, Troy Quane         Will Smith           Tom Holland
# 36872            Greta Gerwig      Saoirse Ronan           Emma Watson
# 36873              Sam Mendes      George MacKay  Dean-Charles Chapman
# 36874   Destin Daniel Cretton  Michael B. Jordan            Jamie Foxx
# 36875         Chinonye Chukwu      Alfre Woodard        Wendell Pierce
#
#          actor_3_name                                    genres  \
# 0         Don Rickles                   Animation Comedy Family
# 1       Kirsten Dunst                  Adventure Fantasy Family
# 2         Ann-Margret                            Romance Comedy
# 3      Loretta Devine                      Comedy Drama Romance
# 4        Martin Short                                    Comedy
# ...               ...                                       ...
# 36871   Rashida Jones  Animation Action Adventure Comedy Family
# 36872   Florence Pugh                     Drama Romance History
# 36873     Mark Strong                         War Drama History
# 36874     Brie Larson                       Drama Crime History
# 36875     Aldis Hodge                                     Drama
#
#                        movie_title  \
# 0                        toy story
# 1                          jumanji
# 2                 grumpier old men
# 3                waiting to exhale
# 4      father of the bride part ii
# ...                            ...
# 36871            spies in disguise
# 36872                 little women
# 36873                         1917
# 36874                   just mercy
# 36875                     clemency
#
#                                                     comb
# 0      Tom Hanks Tim Allen Don Rickles John Lasseter ...
# 1      Robin Williams Jonathan Hyde Kirsten Dunst Joe...
# 2      Walter Matthau Jack Lemmon Ann-Margret Howard ...
# 3      Whitney Houston Angela Bassett Loretta Devine ...
# 4      Steve Martin Diane Keaton Martin Short Charles...
# ...                                                  ...
# 36871  Will Smith Tom Holland Rashida Jones Nick Brun...
# 36872  Saoirse Ronan Emma Watson Florence Pugh Greta ...
# 36873  George MacKay Dean-Charles Chapman Mark Strong...
# 36874  Michael B. Jordan Jamie Foxx Brie Larson Desti...
# 36875  Alfre Woodard Wendell Pierce Aldis Hodge Chino...
#
# [36876 rows x 7 columns]

# %%
final_df = old_df.append(my_df,ignore_index=True)
# Out:
# C:\Users\Rahul\AppData\Local\Temp\ipykernel_30184\2046453413.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = old_df.append(my_df,ignore_index=True)

# %%
final_df
# Out:
#                                            director_name  \
# 0                                          John Lasseter
# 1                                           Joe Johnston
# 2                                          Howard Deutch
# 3                                        Forest Whitaker
# 4                                          Charles Shyer
# ...                                                  ...
# 37508                                          Joel Coen
# 37509                                  Denzel Washington
# 37510                                     Erwin brothers
# 37511  Apichatpong Weerasethakul (director/acreenplay...
# 37512                                                nan
#
#                                             actor_1_name       actor_2_name  \
# 0                                              Tom Hanks          Tim Allen
# 1                                         Robin Williams      Jonathan Hyde
# 2                                         Walter Matthau        Jack Lemmon
# 3                                        Whitney Houston     Angela Bassett
# 4                                           Steve Martin       Diane Keaton
# ...                                                  ...                ...
# 37508                                  Denzel Washington  Frances McDormand
# 37509                                  Michael B. Jordan       Chanté Adams
# 37510                                       Zachary Levi        Anna Paquin
# 37511  Apichatpong Weerasethakul (director/acreenplay...         Elkin Díaz
# 37512                                                nan            unknown
#
#           actor_3_name                    genres                  movie_title  \
# 0          Don Rickles   Animation Comedy Family                    toy story
# 1        Kirsten Dunst  Adventure Fantasy Family                      jumanji
# 2          Ann-Margret            Romance Comedy             grumpier old men
# 3       Loretta Devine      Comedy Drama Romance            waiting to exhale
# 4         Martin Short                    Comedy  father of the bride part ii
# ...                ...                       ...                          ...
# 37508    Bertie Carvel                 Drama War       the tragedy of macbeth
# 37509  Jalon Christian             Drama Romance         a journal for jordan
# 37510     Dennis Quaid                     Drama            american underdog
# 37511   Jeanne Balibar                     Drama                      memoria
# 37512          unknown                     Drama                          NaN
#
#                                                     comb
# 0      Tom Hanks Tim Allen Don Rickles John Lasseter ...
# 1      Robin Williams Jonathan Hyde Kirsten Dunst Joe...
# 2      Walter Matthau Jack Lemmon Ann-Margret Howard ...
# 3      Whitney Houston Angela Bassett Loretta Devine ...
# 4      Steve Martin Diane Keaton Martin Short Charles...
# ...                                                  ...
# 37508  Denzel Washington Frances McDormand Bertie Car...
# 37509  Michael B. Jordan Chanté Adams Jalon Christian...
# 37510  Zachary Levi Anna Paquin Dennis Quaid Erwin br...
# 37511  Apichatpong Weerasethakul (director/acreenplay...
# 37512                      nan unknown unknown nan Drama
#
# [37513 rows x 7 columns]

# %%
final_df.isna().sum()
# Out:
# director_name    0
# actor_1_name     0
# actor_2_name     0
# actor_3_name     0
# genres           3
# movie_title      1
# comb             3
# dtype: int64

# %%
final_df = final_df.dropna(how='any')

# %%
final_df.isna().sum()
# Out:
# director_name    0
# actor_1_name     0
# actor_2_name     0
# actor_3_name     0
# genres           0
# movie_title      0
# comb             0
# dtype: int64

# %%
final_df.to_csv('data2021.csv',index=False)
